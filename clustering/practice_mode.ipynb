# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from load_model import get_cell_dino_model

model = get_cell_dino_model()
csv_path = "../data/png_converted/NCI60_Images.csv"
df = pd.read_csv(csv_path)
# Out:
# /workspace/innoDrug/clustering/dinov2/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /workspace/innoDrug/clustering/dinov2/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /workspace/innoDrug/clustering/dinov2/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
